# %% [markdown]
# ## ENTRENAMIENTO Y PREDICCION RANDOM FOREST

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

# %%
train = pd.read_csv("./train_para_entrenar.csv")
test = pd.read_csv("../predict.csv")

# %%
train
# Out:
#        quilates  porcentaje profundidad  ancho superior  price  \
# 0          0.50                    62.3            55.0   1845
# 1          1.54                    63.6            60.0  10164
# 2          1.32                    61.7            60.0   5513
# 3          1.20                    62.1            55.0   5174
# 4          1.73                    61.2            60.0  10957
# ...         ...                     ...             ...    ...
# 40450      0.40                    62.9            58.0    687
# 40451      0.95                    62.9            58.0   3984
# 40452      0.63                    61.2            56.0   2182
# 40453      1.22                    63.8            55.0   7201
# 40454      0.32                    60.3            60.0    972
#
#        calidad corte_Fair  calidad corte_Good  calidad corte_Ideal  \
# 0                       0                   0                    1
# 1                       0                   1                    0
# ...

# %%
#entrenemos el modelo con 1000 arboles de decision
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)

# %%
modelo = rf.fit(train.drop("price",axis=1),train["price"])

# %%
#tenemos que ajustar nuestro data de test para poder hacer predicciones.
testt = test.drop(["id","x","y","z"],axis=1)

# %%
#convertimos a ordinales las columnas categoricas del test.
test_dummies = pd.get_dummies(testt)

# %%
#hacemos las predicciones

# %%
y_pred = modelo.predict(test_dummies)

# %%
fin_prediccion = pd.DataFrame({"id":test["id"],"price":y_pred})

# %%
fin_prediccion.to_csv("./prediccion_final.csv",index=False) #exportamos el modelo.

# %%
fin_prediccion.shape
# Out:
# (13485, 2)

# %%
fin_prediccion
# Out:
#           id        price
# 0          0   962.602500
# 1          1  6637.684567
# 2          2   809.180333
# 3          3  1837.855976
# 4          4   967.071267
# ...      ...          ...
# 13480  13480   409.445250
# 13481  13481  4375.820267
# 13482  13482   948.221152
# 13483  13483   620.537779
# 13484  13484  4563.725274
#
# [13485 rows x 2 columns]
